# %% [markdown]
# ### Machine Learning for Systems & Control 5SC28 2022-2023
#
# # Exercise set Lecture X: ML basics in python

# %% [markdown]
# In this exercise set you will..

# %% [markdown]
# ## Exercise 1: Name exercise
#
# **a)**
#
# **b)**
#
# **c)**

# %% [markdown]
# ## Exercise 2: Name exercise
#
# **a)**
#
# **b)**
#
# **c)**

# %% [markdown]
# ## Exercise 3: Name exercise
#
# **a)**
#
# **b)**
#
# **c)**
